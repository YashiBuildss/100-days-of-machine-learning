# %%
import sys
# !{sys.executable} -m pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/52.8 kB ? eta -:--:--
#      --------------- ----------------------- 20.5/52.8 kB 72.6 kB/s eta 0:00:01
#      ---------------------- --------------- 30.7/52.8 kB 100.9 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 170.4 kB/s eta 0:00:00
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#      ---------------------------------------- 0.0/121.0 kB ? eta -:--:--
#      -------------------------------------- 121.0/121.0 kB 3.6 MB/s eta 0:00:00
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
pf= pd.read_csv('Iris.csv')
pf.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
pf.shape
# Out:
# (150, 6)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Countplot

# %%
sns.countplot(pf['Species'])
# Out:
# <Axes: xlabel='count', ylabel='Species'>

# %%
pf['SepalLengthCm'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %%
sns.countplot(df['Embarked'])
#df['Survived'].value_counts().plot(kind='bar')

# %% [markdown]
# ## b. PieChart

# %%
pf['PetalWidthCm'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: >

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')

# %% [markdown]
# <div style="border-top:black 2px solid"></div>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
# !{sys.executable} -m  pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
plt.hist(pf['PetalLengthCm'],bins=5)
plt.show()

# %%
sns.distplot(pf['PetalWidthCm'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_6320\45943919.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(pf['PetalWidthCm'])
# <Axes: xlabel='PetalWidthCm', ylabel='Density'>

# %% [markdown]
# ## b. Distplot

# %%
sns.distplot(df['Age'])

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(pf['SepalWidthCm'])
# Out:
# <Axes: ylabel='SepalWidthCm'>

# %%
sns.boxplot(df['Age'])

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
pf['PetalLengthCm'].skew()
# Out:
# np.float64(-0.27446425247378287)
